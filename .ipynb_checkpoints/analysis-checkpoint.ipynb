# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in C:\Users\Lev\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\Lev\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\Lev\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\Lev\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\Lev\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-learn) (3.6.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
import tools

# %% [markdown]
# ### get data

# %%
dataset = sklearn.datasets.load_iris()

feature_names = dataset.feature_names
label_names = dataset.target_names

features = dataset.data
labels = dataset.target


setosas = np.array([features[i] for i in range(features.shape[0]) if labels[i] == 0])
versicolors = np.array([features[i] for i in range(features.shape[0]) if labels[i] == 1])
virginicas = np.array([features[i] for i in range(features.shape[0]) if labels[i] == 2])
print(feature_names)
print(label_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# ### plot graphs

# %%
def scatter2features(i, j, feature_names):
    plt.scatter(setosas[:, i], setosas[:, j],
                color='blue',
                label='setosas')
    plt.scatter(versicolors[:, i], versicolors[:, j],
                color='red',
                label='versicolors')
    plt.scatter(virginicas[:, i], virginicas[:, j],
                color='green',
                label='virginicas')
    plt.xlabel(feature_names[i])
    plt.ylabel(feature_names[j])
    plt.legend()
    

scatter2features(2, 3, feature_names)
plt.figure()
scatter2features(0, 1, feature_names)

# %% [markdown]
# ### k nearest neighbours from point (5.4, 3.7, 3, 2)
# Remember, the function calculates distance using all 4 coordinates.
# Individual 2D scatter plots may be misleading.

# %%
k = 5
point = np.array([5.4, 3.7, 3, 2])
k_neighbours = tools.find_k_nearest_neighbours(k, point, features, labels)
k_neighbour_points = np.array([features[neighbour[0]] for neighbour in k_neighbours])


scatter2features(0, 1, feature_names)
plt.scatter(k_neighbour_points[:, 0], k_neighbour_points[:, 1],
            label = 'k neighbours',
            color = 'pink')
plt.scatter(point[0], point[1],
            label = 'Original point',
            color = 'yellow')
plt.legend()


plt.figure()
scatter2features(2, 3, feature_names)
plt.scatter(k_neighbour_points[:, 2], k_neighbour_points[:, 3],
            label = 'k neighbours',
            color = 'pink')
plt.scatter(point[2], point[3],
            label = 'Original point',
            color = 'yellow')
plt.legend()
